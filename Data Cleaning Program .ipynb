# %%
import pandas as pd
data={
    "Name":["Neha","Rohit",None,"Mehak"],
    "Age":[23,45,None,56],
    "Marks":[34,67,45,None]

}
df=pd.DataFrame(data)
print("\n Orignal Data:")
print(df)
data_clean=df.dropna()
print("\nClean Data (without missing values):")
print(data_clean)
# Out:
#  Orignal Data:
#     Name   Age  Marks
# 0   Neha  23.0   34.0
# 1  Rohit  45.0   67.0
# 2   None   NaN   45.0
# 3  Mehak  56.0    NaN
#
# Clean Data (without missing values):
#     Name   Age  Marks
# 0   Neha  23.0   34.0
# 1  Rohit  45.0   67.0
