# %%
import pandas as pd

# %% [markdown]
# # Reading a .csv (comma separated values) file as a pandas DataFrame

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Printing the first few rows of the dataframes

# %%
df.head
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.tail
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Printing the last few rows of the dataframes

# %%
# checking shape of dataframe
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Printing some statics

# %%
df.describe()
# count: number of non-missing values
# mean
# std: standard deviation
# min: minimum value of the column
# 25%: 25th percentile of the column
# 50%: 50th percentile of the column
# 75%: 75th percentile of the column
# max: maximum value of the col
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Selecting and viewing your Data

# %%
df['Cabin'].head(11)
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# Name: Cabin, dtype: object

# %%
df['Cabin'].tail(11)
# Out:
# 880     NaN
# 881     NaN
# 882     NaN
# 883     NaN
# 884     NaN
# 885     NaN
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, dtype: object

# %%
df[['Name','Age','Survived']].tail(12)
# Out:
#                                               Name   Age  Survived
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0         1
# 880   Shelley, Mrs. William (Imanita Parrish Hall)  25.0         1
# 881                             Markun, Mr. Johann  33.0         0
# 882                   Dahlberg, Miss. Gerda Ulrika  22.0         0
# 883                  Banfield, Mr. Frederick James  28.0         0
# 884                         Sutehall, Mr. Henry Jr  25.0         0
# 885           Rice, Mrs. William (Margaret Norton)  39.0         0
# 886                          Montvila, Rev. Juozas  27.0         0
# 887                   Graham, Miss. Margaret Edith  19.0         1
# 888       Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                          Behr, Mr. Karl Howell  26.0         1
# 890                            Dooley, Mr. Patrick  32.0         0

# %% [markdown]
# # Selecting multiple columns

# %%
df[['Name','Age','Survived']].head(12)
# Out:
#                                                  Name   Age  Survived
# 0                             Braund, Mr. Owen Harris  22.0         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                              Heikkinen, Miss. Laina  26.0         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                            Allen, Mr. William Henry  35.0         0
# 5                                    Moran, Mr. James   NaN         0
# 6                             McCarthy, Mr. Timothy J  54.0         0
# 7                      Palsson, Master. Gosta Leonard   2.0         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0         1
# 10                    Sandstrom, Miss. Marguerite Rut   4.0         1
# 11                           Bonnell, Miss. Elizabeth  58.0         1

# %% [markdown]
# # Checking missing values in the Dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Renaming columna in yOur DataFrame

# %%
df.rename(columns={'PassengerId':'S.no'})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'PassengerId':'S.no'},inplace=True)
df
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
df.rename(columns={'Survived':'ABC','Pclass':'Passenegr_class','Name':'pname'},inplace=True)
df
# Out:
#      S.no  ABC  Passenegr_class  \
# 0       1    0                3
# 1       2    1                1
# 2       3    1                3
# 3       4    1                1
# 4       5    0                3
# ..    ...  ...              ...
# 886   887    0                2
# 887   888    1                1
# 888   889    0                3
# 889   890    1                1
# 890   891    0                3
#
#                                                  pname     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Filtering And Shorting

# %%
df[df['Age']>25]
# Out:
#      S.no  ABC  Passenegr_class  \
# 1       2    1                1
# 2       3    1                3
# 3       4    1                1
# 4       5    0                3
# 6       7    0                1
# ..    ...  ...              ...
# 883   884    0                2
# 885   886    0                3
# 886   887    0                2
# 889   890    1                1
# 890   891    0                3
#
#                                                  pname     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']>50) & (df['Sex']=="male")]
# Out:
#      S.no  ABC  Passenegr_class                                 pname   Sex  \
# 6       7    0                1               McCarthy, Mr. Timothy J  male
# 33     34    0                2                 Wheadon, Mr. Edward H  male
# 54     55    0                1        Ostby, Mr. Engelhart Cornelius  male
# 94     95    0                3                     Coxon, Mr. Daniel  male
# 96     97    0                1             Goldschmidt, Mr. George B  male
# 116   117    0                3                  Connors, Mr. Patrick  male
# 124   125    0                1           White, Mr. Percival Wayland  male
# 150   151    0                2            Bateman, Rev. Robert James  male
# 152   153    0                3                      Meo, Mr. Alfonzo  male
# 155   156    0                1           Williams, Mr. Charles Duane  male
# 170   171    0                1             Van der hoef, Mr. Wyckoff  male
# ...

# %%
df[(df['Age']>50) & (df['Sex']=="male")][["Name","Age","Sex","Survived"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df[(df['Age']>50) & (df['Sex']=="male")][["Name","Age","Sex","Survived"]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
df
# Out:
#      S.no  ABC  Passenegr_class  \
# 0       1    0                3
# 1       2    1                1
# 2       3    1                3
# 3       4    1                1
# 4       5    0                3
# ..    ...  ...              ...
# 886   887    0                2
# 887   888    1                1
# 888   889    0                3
# 889   890    1                1
# 890   891    0                3
#
#                                                  pname     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["pname"] == "Braund, Mr. Owen Harris"]
# Out:
#    S.no  ABC  Passenegr_class                    pname   Sex   Age  SibSp  \
# 0     1    0                3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# ## Droping column in Dataframe

# %%
df.drop(columns=['pname','Cabin'])
# Out:
#      S.no  ABC  Passenegr_class     Sex   Age  SibSp  Parch            Ticket  \
# 0       1    0                3    male  22.0      1      0         A/5 21171
# 1       2    1                1  female  38.0      1      0          PC 17599
# 2       3    1                3  female  26.0      0      0  STON/O2. 3101282
# 3       4    1                1  female  35.0      1      0            113803
# 4       5    0                3    male  35.0      0      0            373450
# ..    ...  ...              ...     ...   ...    ...    ...               ...
# 886   887    0                2    male  27.0      0      0            211536
# 887   888    1                1  female  19.0      0      0            112053
# 888   889    0                3  female   NaN      1      2        W./C. 6607
# 889   890    1                1    male  26.0      0      0            111369
# 890   891    0                3    male  32.0      0      0            370376
#
#         Fare Embarked
# ...

# %% [markdown]
# ## Checking the number of unique value in a column

# %%
#df.Sex.nunique()
df['Sex'].nunique()
# Out:
# 2

# %%
df.Parch.nunique()
# Out:
# 7

# %% [markdown]
# ## Checking the categories

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## Creating a new columns

# %%
df['Fare_In_rs']=df['Fare']*80
df
# Out:
#      S.no  ABC  Passenegr_class  \
# 0       1    0                3
# 1       2    1                1
# 2       3    1                3
# 3       4    1                1
# 4       5    0                3
# ..    ...  ...              ...
# 886   887    0                2
# 887   888    1                1
# 888   889    0                3
# 889   890    1                1
# 890   891    0                3
#
#                                                  pname     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
